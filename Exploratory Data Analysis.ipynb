# %% [markdown]
# # Univariate analysis

# %%
 # Analysis of single variabale (column) Independent

# %% [markdown]
# # Bivariate analysis

# %%
# Analysis of two variable (column) analysis

# %% [markdown]
# # Multi variate analysis

# %%
# analysis of more than two variable (column)

# %% [markdown]
# # Univariate Analysis

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# # a. count plot

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Sex'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Pclass'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Embarked'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
sns.countplot(df['Pclass'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # b. Pie Chart

# %%
 df['Sex'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind = 'pie', autopct='%.2f') # with percentage
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# # a. Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'], bins=10) # bins
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # b. Distplot

# %%
sns.distplot(df['Age']) # curve line = kernel density estimation || Pobability density function X-Axis = Age, Y-Axis = probabiity
# Out:
# /tmp/ipykernel_81631/2513637289.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age']) # curve line = kernel density estimation || Pobability density function X-Axis = Age, Y-Axis = probabiity
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # c. boxplot

# %%
 sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
 sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# np.float64(0.42)

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()  # tell about skewness of columns if it is 0 then column is symmetrical
# Out:
# np.float64(0.38910778230082704)
